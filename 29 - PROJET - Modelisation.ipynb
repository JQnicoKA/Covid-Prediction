# %% [markdown]
# <a href="https://colab.research.google.com/github/MachineLearnia/Python-Machine-Learning/blob/master/29%20-%20Modelisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://raw.githubusercontent.com/JQnicoKA/data/main/covid.csv'
data = pd.read_csv(url, index_col=0, encoding = "ISO-8859-1")
data.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %% [markdown]
# # PRE-PROCESSING

# %%
df = data.copy()
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %% [markdown]
# ## Création des sous-ensembles (suite au EDA)

# %%
missing_rate = df.isna().sum()/df.shape[0]

# %%
blood_columns = list(df.columns[(missing_rate < 0.9) & (missing_rate >0.88)])
viral_columns = list(df.columns[(missing_rate < 0.80) & (missing_rate > 0.75)])

# %%
key_columns = ['Patient age quantile', 'SARS-Cov-2 exam result']

# %%
df = df[key_columns + blood_columns + viral_columns]
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  Hematocrit  \
# Patient ID
# 44477f75e8169d2                    13               negative         NaN
# 126e9dd13932f68                    17               negative    0.236515
# a46b4402a0e5696                     8               negative         NaN
# f7d619a94f97c45                     5               negative         NaN
# d9e41465789c2b5                    15               negative         NaN
#
#                  Hemoglobin  Platelets  Mean platelet volume   \
# Patient ID
# 44477f75e8169d2         NaN        NaN                    NaN
# 126e9dd13932f68    -0.02234  -0.517413               0.010677
# a46b4402a0e5696         NaN        NaN                    NaN
# f7d619a94f97c45         NaN        NaN                    NaN
# d9e41465789c2b5         NaN        NaN                    NaN
#
#                  Red blood Cells  Lymphocytes  \
# Patient ID
# 44477f75e8169d2              NaN          NaN
# ...

# %% [markdown]
# ## TrainTest - Nettoyage - Encodage

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
trainset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    4068
# positive     447
# Name: count, dtype: int64

# %%
testset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    1018
# positive     111
# Name: count, dtype: int64

# %%
def encodage(df):
    code = {'negative':int(0),
            'positive':int(1),
            'not_detected':int(0),
            'detected':int(1)}

    for col in df.select_dtypes('object').columns:
        df.loc[:,col] = df[col].map(code)
        df[col] = pd.to_numeric(df[col], errors='coerce', downcast='integer')

    return df

# %%
def feature_engineering(df):
    df['est malade'] = df[viral_columns].sum(axis=1) >= 1
    df = df.drop(viral_columns, axis=1)
    return df

# %%
def imputation(df):
    #df['is na'] = (df['Parainfluenza 3'].isna()) | (df['Leukocytes'].isna())
    #df = df.fillna(-999)
    df = df.dropna(axis=0)
    return  df

# %%
def preprocessing(df):

    df = encodage(df)
    df = feature_engineering(df)
    df = imputation(df)

    X = df.drop('SARS-Cov-2 exam result', axis=1)
    y = df['SARS-Cov-2 exam result']

    print(y.value_counts())

    return X, y

# %%
X_train, y_train = preprocessing(trainset)
# Out:
# SARS-Cov-2 exam result
# 0    422
# 1     65
# Name: count, dtype: int64

# %%
X_test, y_test = preprocessing(testset)
# Out:
# SARS-Cov-2 exam result
# 0    95
# 1    16
# Name: count, dtype: int64

# %% [markdown]
# ## Procédure d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def evaluation(model):

    model.fit(X_train, y_train)
    ypred = model.predict(X_test)

    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))

    N, train_score, val_score = learning_curve(model, X_train, y_train,
                                              cv=4, scoring='f1',
                                               train_sizes=np.linspace(0.1, 1, 10))


    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %% [markdown]
# ## Modellisation

# %% [raw]
# Ici on va garder le preprocessor qu'on avait trouvé bon dans le preprocessing, et on va l'appliquer aux différents modéles de ML qu'on va tester.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
preprocessor = make_pipeline(PolynomialFeatures(2, include_bias=False), SelectKBest(f_classif, k=10))

# %%
RandomForest = make_pipeline(preprocessor, RandomForestClassifier(random_state=0))
AdaBoost = make_pipeline(preprocessor, AdaBoostClassifier(random_state=0))
# Pour SVM et KNN on doit normaliser, donc on ajoute une procédure de normalisation
SVM = make_pipeline(preprocessor, StandardScaler(), SVC(random_state=0))
KNN = make_pipeline(preprocessor, StandardScaler(), KNeighborsClassifier())

# %%
dict_of_models = {'RandomForest': RandomForest,
                  'AdaBoost' : AdaBoost,
                  'SVM': SVM,
                  'KNN': KNN
                 }

# %%
for name, model in dict_of_models.items():
    print(name)
    evaluation(model)
# Out:
# RandomForest
# [[91  4]
#  [11  5]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        95
#            1       0.56      0.31      0.40        16
#
#     accuracy                           0.86       111
#    macro avg       0.72      0.64      0.66       111
# weighted avg       0.84      0.86      0.85       111
#
# AdaBoost
# [[89  6]
#  [10  6]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        95
#            1       0.50      0.38      0.43        16
#
#     accuracy                           0.86       111
#    macro avg       0.70      0.66      0.67       111
# weighted avg       0.84      0.86      0.85       111
#
# SVM
# [[92  3]
#  [10  6]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93        95
#            1       0.67      0.38      0.48        16
#
# ...

# %% [raw]
#    Donc là les courbes intéressantes sont :
#    - SVM, car la learningcurve du trainset et du testset tendent à se rejoindre, donc on n'est plus en overfitting,  on est content quand il y a plus d'espace entre ces deux courbes
#    - AdaBoost semble aussi intéressant car la learningcurve du test est en tendance haussière
#    - KNN a de bonnes courbes mais on sait que KNN n'est pas adapté à ce genre de problème

# %% [markdown]
# ## OPTIMISATION

# %% [raw]
# Ici on va donc essayer d'optimiser SVM

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# On imprime toute la pipeline en entier pour pouvoir observer les hyper paramètres qu'on peut toucher
# Comment imprimer le détail ??? #TODO
SVM
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('polynomialfeatures',
#                                   PolynomialFeatures(include_bias=False)),
#                                  ('selectkbest', SelectKBest())])),
#                 ('standardscaler', StandardScaler()),
#                 ('svc', SVC(random_state=0))])

# %%
# On crée un dictionnaire d'hyperparamètres qu'on veut tester
# Les noms des clés ne sont pas annodins, svc__ indique au GridSearch que l'hyperparamètre qu'on veut tester est dans
# la "step" svc, et on modifie gamma
hyper_params = {'svc__gamma':[1e-3, 1e-4, 0.0005],
                'svc__C':[1, 10, 100, 1000, 3000],
               'pipeline__polynomialfeatures__degree':[2, 3],
               'pipeline__selectkbest__k': range(45, 60)}

# %% [raw]
# Quand on cherche à tester un ou deux hyperparamètres avec quelques valeurs différentes c'est ok d'utiliser GridSearchCV, car il va tester l'entiereté des combinaisons possibles; mais quand on commence à avoir 4, 5 hyperparamètres différents à tester avec plusieurs dizaines de possibilités, la complexité devient exponentielle et le PC va tourner toute la nuit. Donc dans le cas ou on veut tester beaucoup d'hyperparamètres, on préfèrera utiliser RandomizedSearchCV, qui va tester n_iter combinaisons aléatoires. Alors oui, toutes les combinaisons ne seront pas testées, mais cela peut tout de même donner de bons résultats et sans cramer notre machine.

# %%
#grid = GridSearchCV(SVM, hyper_params, scoring='recall', cv=4)
grid = RandomizedSearchCV(SVM, hyper_params, scoring='recall', cv=4,
                          n_iter=40)
grid.fit(X_train, y_train)

print(grid.best_params_)

y_pred = grid.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# {'svc__gamma': 0.0001, 'svc__C': 3000, 'pipeline__selectkbest__k': 53, 'pipeline__polynomialfeatures__degree': 3}
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        95
#            1       0.50      0.50      0.50        16
#
#     accuracy                           0.86       111
#    macro avg       0.71      0.71      0.71       111
# weighted avg       0.86      0.86      0.86       111

# %% [raw]
# Donc une bonne chose à faire avec RandomizedSearchCV c'est au début de donner des valeurs d'hyperparamètres à tester plutôt larges et de "zoomer" vers les meilleurs paramètres. (On voit le premier coup qu'on a un best parameter de 52 alors qu'on avait testé entre 10 et 100? go rééssayer cette fois entre 40 et 60).

# %%
evaluation(grid.best_estimator_)
# Out:
# [[87  8]
#  [ 8  8]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        95
#            1       0.50      0.50      0.50        16
#
#     accuracy                           0.86       111
#    macro avg       0.71      0.71      0.71       111
# weighted avg       0.86      0.86      0.86       111

# %% [markdown]
# ## Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve

# %%
precision, recall, threshold = precision_recall_curve(y_test, grid.best_estimator_.decision_function(X_test))

# %%
plt.plot(threshold, precision[:-1], label='precision')
plt.plot(threshold, recall[:-1], label='recall')
plt.legend()

# %% [raw]
# Comment lire ce graphique ? En gros si on choisit un seuil de -20, on a un recall de 1, c'est à dire que toutes les personnes qui ont le covid notre modèle leur a bien dit qu'ils avaientle covid, mais c'est facile, on a juste à dire à tout le monde qu'ils ont le covid, mais la précision va en prendre un sacré coup, et c'est exactement ce qui se passe.
# On peut donc trouver le meilleur compromis entre precision et recall, de base c'est le croisement des courbes, représenté souvent par le score f1, mais en fonction de notre cahier des charges, on peut aussi choisir de sacrifier un peu la precision pour un meilleur recall ou l'inverse...

# %%
def model_final(model, X, threshold=0):
    return model.decision_function(X) > threshold

# %%
y_pred = model_final(grid.best_estimator_, X_test, threshold=-1)

# %%
from sklearn.metrics import recall_score

# %%
f1_score(y_test, y_pred)
# Out:
# 0.5116279069767442

# %%
recall_score(y_test, y_pred)
# Out:
# 0.6875
